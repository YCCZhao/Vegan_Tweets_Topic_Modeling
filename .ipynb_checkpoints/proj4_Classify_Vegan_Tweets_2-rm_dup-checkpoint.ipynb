# %% [markdown]
# # Import Libraries

# %%
import gensim
import numpy as np
import spacy
import pickle
import json
import matplotlib.pyplot as plt
import pymongo
import re
from nltk import ngrams
from string import punctuation
from bson.son import SON
from pymongo import MongoClient
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans, MiniBatchKMeans
from gensim.models import CoherenceModel, LdaModel, LsiModel, HdpModel
from gensim.models.wrappers import LdaMallet
from gensim.corpora import Dictionary
import pyLDAvis.gensim

import os, re, operator, warnings
warnings.filterwarnings('ignore')  # Let's not pay heed to them right now
# %matplotlib inline

# %% [markdown]
# # Import Data

# %%
client = MongoClient(port=27017)
db = client.tweet_on_vegan
popular_tweets = db.streaming_tweets
texts = popular_tweets.find({}, {'_id':1,"id":1,"text":1,'is_retweet':1}).skip(400000).limit(100)
for text in texts:
    pass
    #print(text)

# %%
client = MongoClient(port=27017)
db = client.tweet_on_vegan
popular_tweets = db.streaming_tweets
texts = popular_tweets.find({'lang':'en',
                             'text': {'$not': re.compile('…$')}}, 
                            {'_id':0,"text":1})
tweets = [text['text'] for text in texts]

# %%
import pandas as pd
tweets_df = pd.DataFrame(tweets, columns=['tweets'])
tweets_df.sample(5)
# Out:
#                                                    tweets
# 147002          no but deadass. 💀 https://t.co/8Wi2p5C829
# 219479  I've been vegan for 3 years and it was never a...
# 204465  RT @dankbonnet: are you going to be okay????? ...
# 139691    stop trying to turn me vegan america #veganhour
# 277094  Quick ‘n easy #vegan and #keto treat: a ripe #...

# %%
tweets_df.sample(5)
# Out:
#                                                    tweets
# 212256  RT @The__Prototype: Me in the kitchen trying t...
# 177804  RT @beyoncescurls: Me: I could never be a vega...
# 279461  RT @AZHFTB: when you invite a vegan to your bi...
# 195824  Please RT #beauty #makeup Elcie Foundation Fir...
# 95992   Several 10s of thousands varieties of fruits a...

# %% [markdown]
# # Clean Data
#
# * Remove urls
# * Remove user names
# * Remove line breaks
# * Group tweets and count retweets

# %%
# http://stackoverflow.com/a/13752628/6762004
RE_EMOJI = re.compile('[\U00010000-\U0010ffff]', flags=re.UNICODE)
def clean_tweet(x):
    x = x.strip()
    x = RE_EMOJI.sub(r'', x)
    x = re.sub(r'http\S+', '', x, flags=re.MULTILINE)
    #x = re.sub(r'RT\s@\S+', '', x, flags=re.MULTILINE)
    x = re.sub(r'@\S+\s', '', x, flags=re.MULTILINE)
    x = re.sub(r'\n', ' ', x, flags=re.MULTILINE)
    return (''.join(c for c in x if c not in punctuation)).strip()

tweets_df.tweets = tweets_df.tweets.apply(clean_tweet)

tweets_df = (pd.DataFrame(tweets_df.tweets.value_counts())
              .reset_index()
              .rename(columns={'tweets':'retweets', 'index': 'text'}))
tweets_df.sample(5)
# Out:
#                                                      text  retweets
# 127341  Purple Sprout Cafe  Vegan Wheeling  Revisit Ol...         1
# 105480  just tweeting the word vegan gets you at least...         1
# 37962   Nope had my children tested for B12 mostly veg...         1
# 79477                                 extra cheese please         1
# 65821   Check out and like my holistic mystic organic ...         1

# %%
# Checking
#tweets_df.info()
#tweets_df.tail()
for i in range(10):
    print(tweets_df.loc[i,'text'])
# Out:
# RT I want to be a vegan but I’m hungry
# RT Y’all heard Beyoncé it’s VEGAN TIME
# RT Me I could never be a vegan  Beyoncé Vegan time Me
# BREAKING NEWS Mariah Carey has officially become a gas making her the skinniest person alive She says she achieved this skinny feat by “living off a strict diet of air sunlight and lowfat water” She added that she only breathes vegan nonGMO glutenfree air
# yes im vegan yes i eat meat we exist
# RT are you going to be okay
# RT Me in the kitchen trying to make a new vegan recipe because Beyoncé said it’s “Vegan Time”
# RT if ur vegan and u don’t wanna feed ur pets meat get a fuckin bunny
# there is literally NO excuse to still buy dairy milk there are 0 health benefits and plant milk is extremely accessible now it’s an easy switch to make even if you’re not interested in going vegan
# I’ve actually just been eating cleaner Trying my best to be veganplant based even though I️ do fail sometimes I’m Cuban it’s hard af to not eat meat

# %%
# Stop words
nlp = spacy.load("en")

my_stop_words = [u'vegan', u'amp', 
                 u"think", u"thinks", u"thought",
                 u"okay", u"Okay", u"OKAY",
                 u"want", u"wants",u"rt", u"RT"
                 u"amp", u"vegan", u"Vegan", u"VEGAN",
                 u"vegetarian", u"vegetarians", u"Vegetarian", u"VEGETARIAN",                             
                 u"like"]

for stopword in my_stop_words:
    lexeme = nlp.vocab[stopword]
    lexeme.is_stop = True

# %%
from spacy.tokens import Token
from spacy.lang.en.stop_words import STOP_WORDS  # import stop words from language data
stop_words = STOP_WORDS | set(my_stop_words)
stop_words_getter = lambda token: token.is_stop or token.lower_ in stop_words or token.lemma_ in stop_words
Token.set_extension('is_stop', getter=stop_words_getter)  # set attribute with getter

# %%
# we add some words to the stop word list
tweets_spacy_rm_dup = []

for i, tweet in enumerate(tweets_rm_dup_df.text):
    if i % 1000 == 0:
        print(i)
    tweet_tokenized = []
    doc = nlp(tweet)
    for token in doc:
    # if it's not a stop word or punctuation mark, add it to our article!
        if not token.is_stop and not token.is_punct \
        and not token.like_num and not token.pos_ in ['SYM', 'SPACE']\
        and not token.lemma_ == '-PRON-' and token.__len__() >= 2:
            # we add the lematized version of the word
            tweet_tokenized.append(token.lemma_)
    tweets_spacy_rm_dup.append(tweet_tokenized)
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 71000
# 72000
# 73000
# 74000
# 75000
# 76000
# 77000
# 78000
# 79000
# 80000
# 81000
# 82000
# 83000
# 84000
# 85000
# 86000
# 87000
# 88000
# 89000
# 90000
# 91000
# 92000
# 93000
# 94000
# 95000
# 96000
# 97000
# 98000
# 99000
# 100000
# 101000
# 102000
# 103000
# 104000
# 105000
# 106000
# 107000
# 108000
# 109000
# 110000
# 111000
# 112000
# 113000
# 114000
# 115000
# 116000
# 117000
# 118000
# 119000
# 120000
# 121000
# 122000
# 123000
# 124000
# 125000
# 126000
# 127000
# 128000
# 129000
# 130000
# 131000
# 132000
# 133000
# 134000
# 135000
# 136000
# 137000
# 138000
# 139000
# 140000
# 141000
# 142000
# 143000
# 144000

# %%
tweets_twograms_rm_dup = []
for i in range(len(tweets_spacy)):
    twograms = ngrams(tweets_spacy[i], 2)
    temp = []
    for grams in twograms:
        #pass
        temp.append(' '.join(grams))
        
    tweets_twograms_rm_dup.append(temp+tweets_spacy[i])

# %%
len(tweets_twograms_rm_dup)
# Out:
# 145247

# %%
#for ent in tweet_tokenized.ents:
#    print(ent.text, ent.start_char, ent.end_char, ent.label_)

# %%
#for noun_chunks in doc.noun_chunks:
#    print(noun_chunks)

# %% [markdown]
# # Model 1
# * TF-IDF (sklearn)
# * LSA (gensim)

# %%
#import numpy as np
#from nltk.tokenize import word_tokenize, wordpunct_tokenize, WhitespaceTokenizer
#from nltk.chunk import ne_chunk
#from nltk.tag import pos_tag

# Text with some entities
#sample_tweet = np.array(foo.text)
#for t in sample_tweet[:5]:
#    tokens = pos_tag(word_tokenize(t))
#    entities = ne_chunk(tokens)

#foo.text.apply(lambda x: pos_tag(word_tokenize(x)))

# %% [markdown]
# ## TF-IDF (sklearn)

# %%
from sklearn.feature_extraction import text

my_stop_words = text.ENGLISH_STOP_WORDS.union([u'vegan', u'amp', 
                 u"think", u"thinks", u"thought",
                 u"okay", u"Okay", u"OKAY",
                 u"want", u"wants",u"rt", u"RT"
                 u"amp", u"vegan", u"Vegan", u"VEGAN",
                 u"vegetarian", u"vegetarians", u"Vegetarian", u"VEGETARIAN",                             
                 u"like"])

# %%
# Import
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.stem.lancaster import LancasterStemmer

# This uses WordNet (huge lexical database of English words)
stemmer = LancasterStemmer()
analyzer = CountVectorizer().build_analyzer()

def stemmed_words(doc):
    return (stemmer.stem(w) for w in analyzer(doc))

#tfidf = TfidfVectorizer(tokenizer=lambda i:i, lowercase=False)

# Create a vectorizer object to generate term document counts
# Note all the parameters we can use, let's play!
tfidf = TfidfVectorizer(tokenizer=lambda i:i, lowercase=False,
                        stop_words = my_stop_words, 
                        min_df=50, max_df=0.8)
                        #analyzer=stemmed_words)
    
# Get the vectors
sample_tweet_train = tfidf.fit_transform(tweets_twograms_rm_dup)
# Store them in a Pandas DataFrame
#sample_tweet_train_df = pd.DataFrame(sample_tweet_train.todense(), 
                           #columns=[tfidf.get_feature_names()])
#sample_tweet_train_df.head()

# %%
len(tfidf.get_feature_names())
# Out:
# 3990

# %% [markdown]
# ## LSA (gensim)

# %%
# Import
from gensim import corpora, models, similarities, matutils

# %%
# Convert sparse matrix of counts to a gensim corpus
# Need to transpose it for gensim which wants 
# terms by docs instead of docs by terms
tfidf_corpus = matutils.Sparse2Corpus(sample_tweet_train.transpose())

# Row indices
id2word = dict((v, k) for k, v in tfidf.vocabulary_.items())

# This is a hack for Python 3!
id2word = corpora.Dictionary.from_corpus(tfidf_corpus, 
                                         id2word=id2word)

# Build an LSI space from the input TFIDF matrix, mapping of row id to word, and num_topics
# num_topics is the number of dimensions to reduce to after the SVD
# Analagous to "fit" in sklearn, it primes an LSI space
lsi = models.LsiModel(tfidf_corpus, id2word=id2word, num_topics=100)

# Retrieve vectors for the original tfidf corpus in the LSI space ("transform" in sklearn)
lsi_corpus = lsi[tfidf_corpus]

# Dump the resulting document vectors into a list so we can take a look
doc_vecs = [doc for doc in lsi_corpus]

# %% [markdown]
# **Two most retweeted tweets have lots variation. Taking out these variation to see if a better insight is observed**

# %%
# Create an index transformer that calculates similarity based on 
# our space
index = similarities.MatrixSimilarity(doc_vecs, 
                                      num_features=100)

# %%
# Return the sorted list of cosine similarities to the first document
sims = sorted(enumerate(index[doc_vecs[0]]), key=lambda item: -item[1])

#similar_tweet = {}
similar_tweet = []
count = 0
for tweet, similarity in sims:
    if similarity >= 0.9:
        #pass
        #count += 1
        print(tweets_rm_dup_df.loc[tweet, 'text'])
        #similar_tweet.append(tweet)
# Out:
# RT I want to be a vegan but I’m hungry
# Vegan and gluten free donuts that are like heaven people ❤️ maple cookiesandcream and…
# Hello veganhour Blackpool Vegan amp Green Festival happening 10th March You can also book a stay over at vegan hotel amp AFTER PARTY at the Kings Hotel  More info gt
# Please RT recipes food cooking delicious cook recipe Vegan Queso
# Bey “Be vegan with me ”  Me a loyal fan of 20 years who stan’s her every breath and move but also loves fried chicken
#tweets_df = tweets_df.drop(similar_tweet[1:], axis=0)

# %%
#mvp_tweets = mvp_tweets.drop(similar_tweet[2][1:], axis=0)
#mvp_tweets = mvp_tweets.drop(similar_tweet[4][1:], axis=0)
#mvp_tweets = mvp_tweets.drop(similar_tweet[5][1:], axis=0)
#mvp_tweets = mvp_tweets.drop(similar_tweet[6][1:], axis=0)
#mvp_tweets = mvp_tweets.drop(similar_tweet[7][1:], axis=0)

# %%
tweets_rm_dup_df = tweets_df.reset_index()
tweets_rm_dup_df = tweets_rm_dup_df.drop('index', axis=1)

# %%
#tweets_rm_dup_df

# %% [markdown]
# ## TF-IDF v2 (sklearn)

# %%
# This uses WordNet (huge lexical database of English words)
stemmer = LancasterStemmer()
analyzer = CountVectorizer().build_analyzer()

def stemmed_words(doc):
    return (stemmer.stem(w) for w in analyzer(doc))

#tfidf = TfidfVectorizer(tokenizer=lambda i:i, lowercase=False)

# Create a vectorizer object to generate term document counts
# Note all the parameters we can use, let's play!
tfidf = TfidfVectorizer(tokenizer=lambda i:i, lowercase=False,
                        stop_words = my_stop_words, 
                        min_df=100, max_df=0.8)
                        #analyzer=stemmed_words)
    
# Get the vectors
sample_tweet_train = tfidf.fit_transform(tweets_twograms)
# Store them in a Pandas DataFrame
#sample_tweet_train_df = pd.DataFrame(sample_tweet_train.todense(), 
                           #columns=[tfidf.get_feature_names()])
#sample_tweet_train_df.head()

# %% [markdown]
# ## LSA v2 (gensim)

# %%
# Convert sparse matrix of counts to a gensim corpus
# Need to transpose it for gensim which wants 
# terms by docs instead of docs by terms
tfidf_corpus = matutils.Sparse2Corpus(sample_tweet_train.transpose())

# Row indices
id2word = dict((v, k) for k, v in tfidf.vocabulary_.items())

# This is a hack for Python 3!
id2word = corpora.Dictionary.from_corpus(tfidf_corpus, 
                                         id2word=id2word)

# Build an LSI space from the input TFIDF matrix, mapping of row id to word, and num_topics
# num_topics is the number of dimensions to reduce to after the SVD
# Analagous to "fit" in sklearn, it primes an LSI space
lsi = models.LsiModel(tfidf_corpus, id2word=id2word, num_topics=100)

# Retrieve vectors for the original tfidf corpus in the LSI space ("transform" in sklearn)
lsi_corpus = lsi[tfidf_corpus]

# Dump the resulting document vectors into a list so we can take a look
doc_vecs = [doc for doc in lsi_corpus]

# %%
# Create an index transformer that calculates similarity based on 
# our space
index = similarities.MatrixSimilarity(doc_vecs, 
                                      num_features=100)

# %%
# Return the sorted list of cosine similarities to the first document
sims = sorted(enumerate(index[doc_vecs[0]]), key=lambda item: -item[1])

# %%
for tweet, similarity in sims:
    if similarity >= 0.5:
        #pass
        print(mvp_tweets.iloc[tweet, 0])
        #similar_tweet[1].append(tweet)

# %% [markdown]
# # KMean

# %%
# Convert the gensim-style corpus vecs to a numpy array for sklearn manipulations
ng_lsi = matutils.corpus2dense(lsi_corpus, num_terms=100).transpose()
ng_lsi.shape
# Out:
# (145247, 100)

# %%
scaler = StandardScaler()
ng_lsi_standard = scaler.fit_transform(ng_lsi)

# %%
from sklearn.metrics import silhouette_score

SSEs = []
Sil_coefs = []
for k in range(2,52,5):
    print(k)
    #km = KMeans(n_clusters=k, random_state=1)
    km = MiniBatchKMeans(n_clusters=k)
    km.fit(ng_lsi_standard)
    labels = km.labels_
    Sil_coefs.append(silhouette_score(ng_lsi_standard, labels, metric='euclidean'))
    SSEs.append(km.inertia_) 
    
   # print(Sil_coefs)
   # print(labels)
# Out:
# 2
# 7
# 12
# 17
# 22
# 27
# 32
# 37
# 42
# 47

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(15,5), sharex=True, dpi=200)
k_clusters = range(2,52,5)
ax1.plot(k_clusters, Sil_coefs)
ax1.set_xlabel('number of clusters')
ax1.set_ylabel('silhouette coefficient')

# plot here on ax2
ax2.plot(k_clusters, SSEs)
ax2.set_xlabel('number of clusters')
ax2.set_ylabel('SSE');

# %%
# Create KMeans
kmeans = MiniBatchKMeans(n_clusters=17)

# Cluster
ng_lsi_clusters = kmeans.fit_predict(ng_lsi_standard)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.hist(ng_lsi_clusters, bins=16)
plt.title("Number of Tweets in Each Cluster")
plt.xlabel("Cluster Label")
plt.ylabel("Number of Tweets")
# Out:
# Text(0,0.5,'Number of Tweets')

# %%
for i, tweet in enumerate(tweets_df.text):
    if ng_lsi_clusters[i] == 0:
        print(tweet)
# Out:
# You are going to love this Cauliflower Rice Biryani So easy and oh so delicious   … vegan meatlessmonday indianfood
# Me oh I bet this is vegan scanning ingredients Ingredients contains milk Me
# When someone asks you for advice about going vegan and the next day they post themselves eating ChikFilA on snap
# The short lives of KFC chickens which are gassed amp chopped into 9 pieces after just 40 days in a factory are set to be revealed in a shocking BBC documentary  London Evening Standard    KFCcrisis GoVegan Vegan MeatyMarch MeatlessMarch Februdairy
# I’m vegan
# My favorite recipe of all time  Bombay Potatoes   vegan comfortfood indian
# It’s the only way we can work together to change the future for our planet and its animals – and that no matter what you may have been led to believe is all vegans actually want  Vegan Veganuary PlantBased VeagnLife Februdairy MeatyMarch
# that 22 day vegan diet had legénd looking skinnTy
# RT Thanks for bringing homemade vegan hot dogs to the block party and really putting the “commune” into this community event
# Textbook example of serious male disconnect between his deplorable brain and heart  Until we extend our compassion to all living things humanity will not find peace ❤️☮❤️ AnimalRights WomensRights HumanRights CrueltyFree Vegan
# RT Stop paying these psychopaths salaries GoVegan MeatyMarch Vegan
# wow wouldn’t it be nice if there was a VEGAN pancake option
# Get 5  10 Discount at  Use Verified Code AQU143 amp Save on Vitamins Supplements Beauty BodyBuilding Muscle Health Skincare Makeup WeightLoss Vegan Greens Smoothies NonGMOS Munchies Groceries A5
# I understand many of you are vegetarian or vegan amp I respect your decision But if you do eat meat theres a lot to know So this weeks blog covers what to avoid in our meats amp seafood amp how to find the best clean sustainable affordable protein options
# For Th Record I AM not a vegan vegetarian or any other satanic title used to categorize food I AM a MAN that eats HEALTHY for my own well being and because I honor my temple blissed to me by Th Most Highs 913
# This is not a drill Vegan Beyond Sausage arrives at
# RT Just told Chef Jon we are going vegan So what do I eat now What y’all be eating
# RT Beyoncé Just Announced Shes Going Vegan to Prep for Coachella
# your nuggets are the tastiest ever Please make vegan nuggets so I can eat them again I could eat them everyday if they had no egg CrueltyFree MeatlessMarch MeatFreeMonday MeatFreeMarch PETAUK
# The perfect start to BritishPieWeek gentlemen including the vegan pie was obviously a masterstroke
# HAPPY COOKING  MAINCUISINE COOKING RECIPE CUISINE FOOD FOODIE HUNGRY CHEF DINNERTIME FOODCHANNEL VEGAN FOODBLOG FOODPORN   MUST WATCH  Spicy beef and vegetable soup Yukgaejang 육개장  Full Info  Recipe
# tonight Only two missing ingredients
# Talk about imagine being a vegan  Im def counted OUT
# RT LETS FUCKING GO
# Sunday night is pampering time Simple pleasures no guilt Close the bathroom door and turn in a mermaid vegan MothersDay bbloggers Wellbeing beauty psoriasis depression
# The vegan industry or the meat industry
# I’m taking a spin class tomorrow morning for the first time in months so if anyone needs me I’ll be eating a handful of dry almonds as a snack and posting a pic of my paleo gluten free vegan non gmo salad thing on instagram
# New York Trip Day 4 Wine Tasting amp Vegan Friendly Foods
# We do love it when we gain a new Pudologist  veganhour cleverlittletreats
# The Most Delicious Easter Egg This Year Is OFFICIALLY Vegan Dairy amp GlutenFree    BoojaBooja have done miraculous work and have won goodhousemags blind Easter Egg tasting beating 142 other choices to the prize  Get yours …
# Can’t wait to shove 17 vegan burgers up my ass
# if you would like to make your dreams come true too and become a cow check my pinned tweet
# Ours are vegan friendly too as it so happens
# Im seriously going to make these right now Ill keep you posted
# Id rather join Beyoncè on her vegan diet than go to college tomorrow tbh
# Its the biggest challenge humanity has ever faced Its also our greatest opportunity Its TimeToChoose March 20 in Centretown with a free vegan meal and a discussion following Register on Eventbrite climatechange ottawacentre ecoott ottawa
# Fuck it’s a birthday dinner Not a regular dinner Very special Very vegan
# Beyoncé told me to be vegan and I almost listened
# Gotta keep our vegan future bright and fueled up vegankids sandwich lunch whatourkidseat…
# RT The latest Cool Beans Vegan Daily  Thanks to vegan health
# i think i just made the best vegan brownies in existence gordon ramsey could never
# RT The best part about having sex with vegan girls is that they empathize when you cum in 1 minute flat
# I just found out chilli heatwave Doritos are unintentionally vegan and it cured my depression
# I can see your argument and I respect why you have made the choice you have to become a vegan I just dont look at that instance the same way as you I would never force my views or lifestyle  on to another human but I just dont put animals on that same level
# Im Vegan  Pig  Samsung Galaxy S7 Full Wrap Case  vegan veganism veganclothing veganuk animalwelfareleague crueltyfree veganlife vegans vegansvegetarians vegetariansvegans veganuk
# French meat eatery attacked Vegan Terror painted on wall  via  Isme bhi BJP ka haath hai Kyun
# latestvegannews vegan UK Supermarket Iceland Releases New Beefy PlantBased Burger
# take a minute to read this

# %% [markdown]
# # LDA

# %%
# Import
from nltk.stem.lancaster import LancasterStemmer

# This uses WordNet (huge lexical database of English words)
stemmer = LancasterStemmer()
analyzer = CountVectorizer().build_analyzer()

def stemmed_words(doc):
    return (stemmer.stem(w) for w in analyzer(doc))

count_vectorizer = CountVectorizer(tokenizer=lambda i:i, lowercase=False,
                                   stop_words = my_stop_words, 
                                   min_df=100, max_df=0.8)
                                  #analyzer=stemmed_words)

# Create a vectorizer object to generate term document counts
# Note all the parameters we can use, let's play!
#cv = CountVectorizer(token_pattern='[a-z][a-z]+',
#                     stop_words = 'english')
# Get the vectors
count_vectorizer.fit(tweets_twograms)
counts = count_vectorizer.transform(tweets_twograms).transpose()
# Store them in a Pandas DataFrame
#sample_tweet_train_df = pd.DataFrame(sample_tweet_train.todense(), columns=[stem_vectorizer.get_feature_names()])
#ng_train_df.head()

# %%
corpus = matutils.Sparse2Corpus(counts)

id2word = dict((v, k) for k, v in count_vectorizer.vocabulary_.items())

lda = models.LdaModel(corpus=corpus, num_topics=10, id2word=id2word, passes=20)

lda.print_topics(num_words=10)
# Out:
# [(0,
#   '0.075*"eat" + 0.043*"meat" + 0.032*"food" + 0.030*"diet" + 0.024*"lol" + 0.022*"plant" + 0.018*"need" + 0.018*"option" + 0.016*"fuck" + 0.016*"eat meat"'),
#  (1,
#   '0.089*"organic" + 0.056*"use" + 0.051*"crueltyfree" + 0.047*"product" + 0.037*"natural" + 0.037*"wanna" + 0.036*"shop" + 0.030*"beauty" + 0.030*"save" + 0.026*"skincare"'),
#  (2,
#   '0.032*"recipe" + 0.026*"veggie" + 0.023*"cream" + 0.021*"lunch" + 0.020*"food" + 0.018*"soup" + 0.016*"cooking" + 0.016*"plantbas" + 0.015*"sauce" + 0.014*"ice"'),
#  (3,
#   '0.044*"chicken" + 0.038*"yes" + 0.030*"add" + 0.019*"long" + 0.019*"white" + 0.017*"bacon" + 0.015*"sorry" + 0.015*"believe" + 0.014*"sandwich" + 0.014*"taco"'),
#  (4,
#   '0.025*"good" + 0.025*"try" + 0.023*"food" + 0.023*"know" + 0.023*"look" + 0.019*"day" + 0.016*"eat" + 0.015*"pizza" + 0.014*"today" + 0.014*"week"'),
#  (5,
#   '0.032*"free" + 0.021*"protein" + 0.018*"order" + 0.016*"right" + 0.015*"high" + 0.015*"beyonce" + 0.014*"cruelty" + 0.014*"coachella" + 0.013*"follow" + 0.012*"friendly"'),
#  (6,
#   '0.029*"chocolate" + 0.029*"milk" + 0.028*"cheese" + 0.024*"free" + 0.020*"cake" + 0.019*"glutenfree" + 0.015*"gluten" + 0.013*"dog" + 0.013*"gluten free" + 0.012*"butter"'),
#  (7,
#   '0.054*"’" + 0.037*"animal" + 0.027*"people" + 0.019*"say" + 0.019*"eat" + 0.016*"thing" + 0.016*"life" + 0.016*"good" + 0.015*"time" + 0.013*"meat"'),
#  (8,
#   '0.087*"recipe" + 0.040*"easy" + 0.038*"video" + 0.033*"cook" + 0.028*"thank" + 0.025*"salad" + 0.024*"healthyfood" + 0.023*"late" + 0.022*"meal" + 0.020*"pet"'),
#  (9,
#   '0.025*"love" + 0.021*"health" + 0.017*"food" + 0.015*"new" + 0.013*"place" + 0.012*"month" + 0.012*"veganism" + 0.011*"plantbased" + 0.010*"help" + 0.010*"check"')]

# %% [markdown]
# # Gensim Model

# %%
dictionary = Dictionary(tweets_twograms)
corpus = [dictionary.doc2bow(tweet) for tweet in tweets_twograms]

# %% [markdown]
# # LSI

# %%
lsimodel = LsiModel(corpus=corpus, num_topics=20, id2word=dictionary)
lsimodel.show_topics(num_topics=20)  # Showing only the top 5 topics

# %% [markdown]
# # HDP

# %%
hdpmodel = HdpModel(corpus=corpus, id2word=dictionary)
hdpmodel.show_topics()

# %% [markdown]
# # LDA

# %%
ldamodel = LdaModel(corpus=corpus, num_topics=10, passes=20, id2word=dictionary)
ldamodel.show_topics()
# Out:
# [(0,
#   '0.007*"like" + 0.006*"plant" + 0.006*"video" + 0.005*"the" + 0.005*"base" + 0.004*"new" + 0.004*"what" + 0.003*"like video" + 0.003*"eat" + 0.003*"plant base"'),
#  (1,
#   '0.019*"free" + 0.007*"gluten" + 0.006*"gluten free" + 0.004*"beauty" + 0.004*"crueltyfree" + 0.004*"cruelty" + 0.003*"use" + 0.003*"natural" + 0.003*"skincare" + 0.003*"makeup"'),
#  (2,
#   '0.015*"not" + 0.015*"animal" + 0.009*"people" + 0.008*"diet" + 0.005*"meat" + 0.005*"eat" + 0.004*"need" + 0.004*"if" + 0.003*"the" + 0.003*"year"'),
#  (3,
#   '0.005*"recipe" + 0.005*"food" + 0.005*"glutenfree" + 0.004*"today" + 0.004*"dinner" + 0.004*"delicious" + 0.004*"chocolate" + 0.004*"sweet" + 0.004*"cooking" + 0.004*"veggie"'),
#  (4,
#   '0.006*"day" + 0.005*"food" + 0.004*"wait" + 0.004*"’s" + 0.004*"raw" + 0.003*"health" + 0.003*"weight" + 0.003*"month" + 0.003*"new" + 0.003*"the"'),
#  (5,
#   '0.021*"not" + 0.011*"the" + 0.009*"thank" + 0.005*"good" + 0.005*"cheese" + 0.005*"bad" + 0.004*"be" + 0.004*"do" + 0.004*"late" + 0.003*"not eat"'),
#  (6,
#   '0.019*"recipe" + 0.012*"rt" + 0.005*"please" + 0.005*"breakfast" + 0.005*"cheese" + 0.004*"healthyfood" + 0.004*"cook" + 0.004*"please rt" + 0.003*"add" + 0.003*"delicious"'),
#  (7,
#   '0.024*"eat" + 0.014*"good" + 0.013*"not" + 0.011*"food" + 0.011*"meat" + 0.009*"be" + 0.009*"have" + 0.008*"try" + 0.008*"know" + 0.005*"look"'),
#  (8,
#   '0.012*"milk" + 0.005*"buy" + 0.003*"drink" + 0.003*"organic" + 0.003*"water" + 0.002*"almond" + 0.002*"cow" + 0.002*"one" + 0.002*"make" + 0.002*"hair"'),
#  (9,
#   '0.028*"be" + 0.025*"go" + 0.021*"’" + 0.006*"not" + 0.006*"time" + 0.006*"beyoncé" + 0.006*"fuck" + 0.006*"say" + 0.005*"to" + 0.005*"get"')]

# %% [markdown]
# # pyLDAvis

# %%
pyLDAvis.enable_notebook()
pyLDAvis.gensim.prepare(ldamodel, corpus, dictionary)
# Out:
# PreparedData(topic_coordinates=            Freq  cluster  topics         x         y
# topic
# 7      12.928627        1       1 -0.142449 -0.111212
# 2      12.602065        1       2 -0.153813  0.021011
# 9      11.476384        1       3 -0.158808 -0.058914
# 3      10.626929        1       4  0.165446 -0.150065
# 5      10.310394        1       5 -0.103043  0.007404
# 6       9.686477        1       6  0.171549 -0.133643
# 0       9.189126        1       7  0.009369  0.083094
# 4       8.178579        1       8  0.052518  0.071298
